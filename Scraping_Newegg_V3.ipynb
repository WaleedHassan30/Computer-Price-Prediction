# %% [markdown]
# # <center> NewEgg.Com Scraper Program
# # For Any Category on NewEgg Web Site - Beta v1.0
#
# ###  - November 26th, 2022
#
# #### By: Waleed Hassan
#
# ### Problem Statement
# - Collecting all computers from the Internet, comparing their specifications, and predicting the prices of those specifications for each category.
#
# ## And You Can To Scrap Any Category From NewEgg.com Site and get all Information for All Products. Just
# - (1) Go to www.newegg.com, go to the any section.
# - (2) Copy and paste the url from Browser Address.
# - (3) This is a "Supervised Scraper", meaning it will mostly be automated, but you will be alerted to take action when necessary.
# - (4) After the webscraping is successful, you will have an option to concatenate all of the pages you scraped together into one csv file
# - (5) If you have any issues or errors, "PRESS CTRL + C" to quit the program in the terminal .
# Disclaimer: Newegg may ban you for a 48 - 72 hours for webscraping their data, then you may resume.
#  Also, please consider executing during the day, with tons of web traffic to their site in your respective area. Please Useing VPN Application to ignore that for every Sections or split your pages to 25% for each procees scraping.
#
# ### Happy Scraping!
# Eng.Waleed Hassan
#
# <hr>

# %% [markdown]
# ## <center> Main Program Logic

# %% [markdown]
# ## Packages importing

# %%
import pandas as pd
import numpy as np
import warnings
import os
from Python_Files.scraping_newegg import *  # All Python Code as a py File
warnings.filterwarnings("ignore")
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
df_Desktop_Computers = Scraping_URL_Cat(
    1, 100, "https://www.newegg.com/global/sa-en/Desktop-Computers/SubCategory/ID-10/Page-", "?Tid=1533555")
df_Desktop_Computers.to_csv("Downloaded_Products/df_Desktop_Computers.csv")
print("Desktop_Computers Saved")
##############################################################################################################################
df_All_in_one_Computers = Scraping_URL_Cat(
    1, 100, "https://www.newegg.com/global/sa-en/All-in-One-Computers/SubCategory/ID-3309/Page-", "?Tid=1533558")
df_All_in_one_Computers.to_csv(
    "Downloaded_Products/df_All_in_one_Computers.csv")
print("All_in_one_Computers Saved")

##############################################################################################################################
df_Gaming_Desktop = Scraping_URL_Cat(
    1, 100, "https://www.newegg.com/global/sa-en/Gaming-Desktops/SubCategory/ID-3742/Page-", "")
df_Gaming_Desktop.to_csv("Downloaded_Products/df_Gaming_Desktop.csv")
print("Gaming_Desktop_Computers Saved")

##############################################################################################################################
df_Labtop = Scraping_URL_Cat(
    1, 100, "https://www.newegg.com/global/sa-en/Laptops-Notebooks/SubCategory/ID-32/Page-", "?Tid=1533500")
df_Labtop.to_csv(
    "Downloaded_Products/df_Labtop.csv")
print("Labtop_Computers Saved")
##############################################################################################################################
df_Gaming_Labtop = Scraping_URL_Cat(
    1, 100, "https://www.newegg.com/global/sa-en/Gaming-Laptops/SubCategory/ID-3365/Page-", "?Tid=1533504")
df_Gaming_Labtop.to_csv(
    "Downloaded_Products/df_Gaming_Labtop.csv")
print("Gaming_Labtop_Computers Saved")
##############################################################################################################################
df_Labtop_2_1 = Scraping_URL_Cat(
    1, 100, "https://www.newegg.com/global/sa-en/2-in-1-Laptops/SubCategory/ID-3090/Page-", "?Tid=1533503")
df_Labtop_2_1.to_csv(
    "Downloaded_Products/df_Labtop_2_1.csv")
print("Labtop_2_1_Computers Saved")
##############################################################################################################################
df_Chrome_Book = Scraping_URL_Cat(
    1, 100, "https://www.newegg.com/global/sa-en/Chromebooks/SubCategory/ID-3220/Page-", "?Tid=1533508")
df_Chrome_Book.to_csv(
    "Downloaded_Products/df_Chrome_Book.csv")
print("Chrome_Book_Computers Saved")
##############################################################################################################################
df_Business_Labtop = Scraping_URL_Cat(
    1, 100, "https://www.newegg.com/global/sa-en/Business-Laptops/SubCategory/ID-3413/Page-", "?Tid=1533506")
df_Business_Labtop.to_csv(
    "Downloaded_Products/df_Business_Labtop.csv")
print("Business_Labtop Saved")
##############################################################################################################################
df_MacBook = Scraping_URL_Cat(
    1, 100, "https://www.newegg.com/global/sa-en/Apple-Laptops-Notebooks/BrandSubCat/ID-1759-32/Page-")
df_MacBook.to_csv(
    "Downloaded_Products/df_MacBook.csv")
print("MacBook_Computers Saved")
##############################################################################################################################
df_imac = Scraping_URL_Cat(
    1, 100, "https://www.newegg.com/Apple-Desktop-Computers/BrandSubCat/ID-1759-10/Page-", "")
df_imac.to_csv(
    "Downloaded_Products/df_imac.csv")
print("imac_Computers Saved")
##############################################################################################################################

# %%
df_Business_Labtop = Scraping_URL_Cat(
    1, 15, "https://www.newegg.com/global/sa-en/Business-Laptops/SubCategory/ID-3413/Page-", "?Tid=1533506")
df_Business_Labtop.to_csv(
    "Downloaded_Products/df_Business_Labtop-1-15.csv")
print("Business_Labtop Saved")

#os.system("shutdown /h") #hibernate
# Out:
# URL: https://www.newegg.com/global/sa-en/msi-ws-series-ws76-11um-468-workstation/p/N82E16834156008 has been Downloaded: page-1 , 1 Product
# URL: https://www.newegg.com/global/sa-en/p/N82E16834156270 has been Downloaded: page-1 , 2 Product
# URL: https://www.newegg.com/global/sa-en/p/N82E16834156271 has been Downloaded: page-1 , 3 Product
# URL: https://www.newegg.com/global/sa-en/msi-ws-series-ws76-11uk-469-workstation/p/N82E16834156009 has been Downloaded: page-1 , 4 Product
# URL: https://www.newegg.com/global/sa-en/msi-wf-series-wf76-11ui-400-workstation/p/N82E16834156012 has been Downloaded: page-1 , 6 Product
# URL: https://www.newegg.com/global/sa-en/msi-ws-series-ws66-11ukt-269-workstation/p/N82E16834155945 has been Downloaded: page-1 , 7 Product
# URL: https://www.newegg.com/global/sa-en/msi-ws-series-ws76-11uk-470-workstation/p/N82E16834156010 has been Downloaded: page-1 , 8 Product
# ...

# %%
df_Business_Labtop.tail(2)
# Out:
#      Page Number  Product_no.                                        Product_URL                                      Title_Product     Product_Group Product_Rate                                     Product_Images          Last_Update         Price shipping   Brand    Series  Model   Color       Operating System                            CPU    Screen Memory     Storage           Graphics Card Video Memory  Dimensions (W x D x H)     Weight       Other Features                CPU Type CPU Speed Turbo Frequency      Number of Cores CPU L3 Cache      Chipset Screen Size Touchscreen Wide Screen Support Display Type Panel   Resolution            LCD Features                 GPU/VPU     Graphic Type Virtual Reality Ready     SSD Memory Speed                Memory Spec Memory Slot (Total) Memory Slot (Available)               Max Memory Supported Optical Drive Type              LAN                   WLAN      Bluetooth          USB               Thunderbolt          HDMI  \
# ...

# %%
df_Business_Labtop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 239 entries, 0 to 238
# Data columns (total 79 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Page Number              239 non-null    int64
#  1   Product_no.              239 non-null    int64
#  2   Product_URL              239 non-null    object
#  3   Title_Product            239 non-null    object
#  4   Product_Group            239 non-null    object
#  5   Product_Rate             239 non-null    object
#  6   Product_Images           239 non-null    object
#  7   Last_Update              239 non-null    object
#  8   Price                    239 non-null    object
#  9   shipping                 239 non-null    object
#  10  Brand                    239 non-null    object
#  11  Series                   239 non-null    object
#  12  Model                    239 non-null    object
#  13  Color                    239 non-null    object
# ...

# %%
df_Desktop_Computers["Product_URL"].value_counts()
# Out:
# https://www.newegg.com/global/sa-en/hp-z-series-z840-business-desktops-workstations/p/1VK-001E-0BHG4        3
# https://www.newegg.com/global/sa-en/hp-z-series-z840-business-desktops-workstations/p/1VK-001E-0BJR5        3
# https://www.newegg.com/global/sa-en/hp-z-series-z840-business-desktops-workstations/p/1VK-001E-0BHG0        3
# https://www.newegg.com/global/sa-en/hp-z-series-z840-business-desktops-workstations/p/1VK-001E-0BJP3        3
# https://www.newegg.com/global/sa-en/hp-z-series-z620-business-desktops-workstations/p/1VK-001E-0EUZ7        3
# https://www.newegg.com/global/sa-en/hp-z-series-z840-business-desktops-workstations/p/1VK-001E-0BK20        3
# https://www.newegg.com/global/sa-en/hp-z-series-z840-business-desktops-workstations/p/1VK-001E-0BJ66        3
# https://www.newegg.com/global/sa-en/hp-z-series-z840-business-desktops-workstations/p/1VK-001E-0BGT4        3
# ...

# %%
df_imac = Scraping_URL_Cat(
    41, 42, "https://www.newegg.com/Apple-Desktop-Computers/BrandSubCat/ID-1759-10/Page-", "")
df_imac.to_csv(
    "Downloaded_Products/df_imac-41-42.csv")
print("imac_Computers Saved")
# Out:
# URL: https://www.newegg.com/p/2TS-0008-00ZY1 has been Downloaded: page-1 , 1 Product
# URL: https://www.newegg.com/p/2TS-0008-00MF4 has been Downloaded: page-1 , 2 Product
# URL: https://www.newegg.com/p/2TS-0008-00WV5 has been Downloaded: page-1 , 3 Product
# URL: https://www.newegg.com/p/2TS-0008-00FK8 has been Downloaded: page-1 , 4 Product
# URL: https://www.newegg.com/p/2TS-0008-00NV8 has been Downloaded: page-1 , 5 Product
# URL: https://www.newegg.com/p/2TS-0008-00WW0 has been Downloaded: page-1 , 6 Product
# URL: https://www.newegg.com/p/2TS-0008-00WA0 has been Downloaded: page-1 , 7 Product
# URL: https://www.newegg.com/p/2TS-0008-01R31 has been Downloaded: page-1 , 8 Product
# URL: https://www.newegg.com/p/2TS-0008-00X62 has been Downloaded: page-1 , 9 Product
# URL: https://www.newegg.com/p/2TS-0008-00NY4 has been Downloaded: page-1 , 10 Product
# URL: https://www.newegg.com/p/2TS-0008-00NY6 has been Downloaded: page-1 , 11 Product
# ...

# %%
df_imac.tail(2)
# Out:
#      Page Number  Product_no.                              Product_URL                                      Title_Product      Product_Group Product_Rate                                     Product_Images          Last_Update        Price  shipping           Type Form Factor  Colors           Monitor       CPU Type CPU Speed   SSD Screen Size Date First Available                    Audio      Bluetooth  Brand Card Reader      Display Feature          Ethernet        GPU/VGA Type  HDD  HDD RPM      Keyboard Keyboard Type        LAN Speed Memory Capacity          Mouse Mouse Type            Operating System Optical Drive Type Part Number    RJ45 Rear USB       Screen Type Series Speaker Configuration                                   Special Features Touchscreen    Video Ports                        WLAN     Weight                                      Wireless Card                                      Graphics Card Maximum Memory Supported      Package Contents Software Included  \
# ...

# %% [markdown]
# - Each page is supposed to have 36 products .. We have lost some products for reasons of site protection and changing the proxy for each upload of 10 products

# %%
# Each page is supposed to have 36 products .. We have lost some products for reasons of site protection and changing the proxy for each upload of 10 products
df_imac["Page Number"].value_counts()
# Out:
# 27    36
# 28    36
# 29    36
# 30    36
# 31    36
# 32    36
# 35    36
# 36    36
# 37    36
# 39    36
# 26    35
# 33    35
# 34    35
# 40    35
# 38    34
# Name: Page Number, dtype: int64
